# %% [markdown]
# # Geospatial Analysis using Python
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://gishub.org/geemap-colab)
#
# <style type="text/css">
# 	table.tableizer-table {
# 		font-size: 12px;
# 		border: 1px solid #CCC;
# 		font-family: Arial, Helvetica, sans-serif;
# 	}
# 	.tableizer-table td {
# 		padding: 4px;
# 		margin: 3px;
# 		border: 1px solid #CCC;
#     text-align: left;
# 	}
# 	.tableizer-table th {
# 		background-color: #104E8B;
# 		color: #FFF;
# 		font-weight: bold;
#         text-align: left;
# 	}
#     .tableizer-firstrow {
#     text-align: left;
#     }
# </style>
# <table class="tableizer-table">
# <thead><tr class="tableizer-firstrow"><th>Module</th><th>Topics</th><th>Activities</th></tr></thead><tbody>
#  <tr><td>M1 Basics of remote sensing</td><td>Introduction, Remote sensing for Earth observation, Remote Sensing Workflow, Electromagnetic Energy, Viewing Parameters, Sensor Parameters, Spatial Resolution, Spectral Resolution, Radiometric resolution, Temporal Resolution, Imaging Sensors, Create Google and Earth Engine accounts</td><td>M1L0 Meeting Lecturers and Course Introduction LX Lecture Name PX Practicum Name</td></tr>
#  <tr><td>M2 Data Acquisition and storage</td><td>Platforms and missions, Types of Multispectral Imaging Sensor Systems, Satellite Characteristics, Aerial Photography, Satellite Imagery (Cameras, Scanners), Active sensors, Passive sensors, Various examples of sensors and applications</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M3 Image principles</td><td>Properties of digital image, Data formats Types of Digital Images, Tri-stimuli model Color spaces, Image display (FCC, Origins and nature of digital image), components of image processing system, Visual perception, Basics of pixels, bands, and sampling</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M4 Setting Up the Environment</td><td>Conda, Colab Notebooks, geemap, other Python tools for satellite data acquisition and data storage</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M5 Intro to Earth Engine platform</td><td>Big Data Platforms for Remote Sensing, Earth Engine Platform, EE Primitives, Earth Engine API</td><td>M5L1 Big Data Approach in Remote Sensing M5L2 Intro to Google Earth Engine M5P1 First Steps with Earth Engine (playing with SRTM?)</td></tr>
# <tr><td>M6 Image Interpretation.</td><td>Quantitative Analysis of ERS data, Types of Pictoral Data Products, Image interpretation strategy: Levels of Interpretation Keys. Process of Image Interpretation, Interpretation of Aerial Photo, General procedure for photo interpretation</td><td>LX Lecture Name LX Lab Name M6P1 Desciphering an image (forest fire)</td></tr>
#  <tr><td>M7 Image enhancement</td><td>Gery level transform, histogram processing, arithmetic/logic operations, spatial filtering,    exploratory Image analysis Using Python</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M8 Image corrections (preprocessing)</td><td>Image corrections through geometric / radiometric transforms</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M9 Image Transformations</td><td>Transformationss in frequency domain, Fourier transform, frequency domain filters and its applications, periodic noise removal, Principle component analysis. Python tools for image transformation</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M10 Spectral indices</td><td>Vegetation indices, Soil Indices, Water indices</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M11 Unsupervised Classification</td><td>K- Mean Clustering, ISODATA clustering, Hierarchical Clustering</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M12 Supervised Classification</td><td>Minimum Distance to Mean, Maximum Likelihood, Hypercube, Mahanolobis distance</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M13 Soft Classification Techniques</td><td>Hybrid classification, Knowledge Engineer, Fuzzy Classification, Object Oriented Classification</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M14 Exploratory Data Analysis</td><td>Classification and segmentation using Python</td><td>LX Lecture Name LX Lab Name</td></tr>
#  <tr><td>M15 Validation of Image Classification</td><td>Kappa Accuracy, Overall Accuracy, Regression</td><td>LX Lecture Name LX Lab Name</td></tr>
# </tbody></table>
#
#
# ## 1. Description
#
#
# <p>This repository is for lab work for the course Geospatial Analysis using Python. First you have to create conda environment as this lab work will use multiple Python packages to work with raster data. To set up a local <code class="highlighter-rouge">conda</code> environment, download <a href="https://raw.githubusercontent.com/geohackweek/tutorial_contents/master/raster/environment.yml">this conda environment
# definition</a> and create an environment like so:</p>
#
# Or if you have downloaded the repository which containes the template for the lab work of the course then proceed as follows:
#
# - Open the command prompt
# - change your working directory to the downloaded repository
#  > <b><i>  cd  &lt; Path to the folder containing the notebooks &gt; </i></b>
#
# - Run the following commands in the command prompt:
# > <b><i> conda env create -f env_geospatial.yml </i></b>
# > <b><i> activate geospatial</i></b>
#
# ## 2. Usage
#
# * **Step 1:** Explore this repository and open any available Jupyter notebook in your browser (e.g., [Introduction to Raster Data](./LabWork/01_raster_concepts.ipynb)
# * **Step 2:** If you would like to execute cells in the notebook interactively, then you can click either [Run in Google Colab](https://colab.research.google.com/github/giswqs/earthengine-py-notebooks/blob/master/Template/template.ipynb) to execute code interactively. This will allow you to add your own script.
#
#
# ## 3. Hands on Exercises:
#  - ### Lab -1 : Basics of pixels, bands, and sampling
#  > - [Introduction to Raster Data](./LabWork/01_raster_concepts.ipynb)
#  > - [Raster Formats and Libraries](./LabWork/02_formatsandlibraries.ipynb)
#  > - [Working with Raster Datasets](./LabWork/03_workingwithrasters.ipynb)
